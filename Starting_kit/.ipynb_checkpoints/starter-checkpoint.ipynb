# %% [markdown]
# # I. Introduction
# This notebook is to guide you through the first month of internship when you can only work with your personal computer from home, i.e. no access to intern code / data. The main purpose of this period is to build a state of the art for interpretability and AutoML. During the article reading, you might want to (1) take notes that will be greatly helpful when you write your final report at the end of the internship; (2) test / implement / improve those litterature algorithms using some public dataset. This notebook shows you how to:
#     - load public datasets from financial domains;
#     - explore the datasets and do some necessary data engineering,
#     - apply a ML pipeline on it (where AutoML / HP selection comes in)
#     - and interpret the result (where interpretability comes in).

# %% [markdown]
# # II. Data
# MLBox is a AutoML toolkit that 'focuses' on banking / financial data. Compare to some classical datasets, those data show some specifics: non-numeric features (e.g. names, adresses, ...), time series features (e.g. log, tracking, ...). In the shared dropbox folder, we have collected some similar public datasets, each of which is associated with a .info file that summarizes some essential properties of the dataset. In this section, we use one of them to demonstrate the entire workflow.

# %%
Data_dir = './Data/banking-dataset-marketing-targets/' # set dataset directory

# %%
# read into the dataset
import os
import pandas as pd

D_tr = pd.read_csv(os.path.join(Data_dir, 'train.csv'))

# %%
D_tr.head()
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# 4         no

# %%
D_tr.shape
# Out:
# (31647, 18)

# %%
y_tr = D_tr['subscribed'] # from the info file, we know the target column in 'subscribed'
X_tr = D_tr[[col for col in D_tr.columns if not col in ['ID', 'subscribed']]] # we extract feature columns

# %%
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       56        admin.   married    unknown      no     1933      no   no
# 1       31       unknown   married  secondary      no        3      no   no
# 2       27      services   married  secondary      no      891     yes   no
# 3       57    management  divorced   tertiary      no     3287      no   no
# 4       31    technician   married  secondary      no      119     yes   no
# 5       33    management    single   tertiary      no        0     yes   no
# 6       56       retired   married  secondary      no     1044      no   no
# 7       50    technician    single  secondary      no     1811      no   no
# 8       45   blue-collar  divorced  secondary      no     1951     yes   no
# 9       35        admin.   married  secondary      no     1204      no   no
# 10      36      services  divorced  secondary     yes        0      no  yes
# 11      35   blue-collar   married  secondary      no     -151     yes   no
# 12      44      services   married  secondary      no      237     yes   no
# 13      39    management    single  secondary      no     1877     yes   no
# 14      43   blue-collar   married  secondary      no      960     yes   no
# 15      41      services    single  secondary      no      260      no   no
# 16      53    technician   married  secondary      no      719     yes   no
# 17      64    management   married   tertiary      no     6251      no   no
# 18      44   blue-collar   married    primary      no     4031     yes   no
# 19      48   blue-collar  divorced  secondary      no      501     yes   no
# 20      60    management   married   tertiary      no      328     yes   no
# 21      29        admin.    single   tertiary      no      507     yes   no
# 22      30        admin.  divorced  secondary      no       78     yes   no
# 23      39    management   married   tertiary      no      285     yes   no
# 24      42        admin.    single  secondary      no      684      no   no
# 25      31    management   married   tertiary      no     4720     yes   no
# 26      60       retired   married    primary      no    17413      no   no
# 27      33      services   married  secondary      no      184     yes   no
# 28      45    technician   married  secondary      no      858      no   no
# 29      53     housemaid    single    primary      no       80      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 31617   28    technician   married  secondary      no      880     yes   no
# 31618   21   blue-collar    single  secondary     yes      -59     yes  yes
# 31619   59       retired   married    unknown      no        0      no   no
# 31620   45    management   married   tertiary      no      726     yes  yes
# 31621   32      services  divorced  secondary      no      130     yes   no
# 31622   79       retired  divorced    primary      no     2787      no   no
# 31623   57    technician    single  secondary      no      104      no   no
# 31624   50    management   married   tertiary      no     5108     yes   no
# 31625   56  entrepreneur   married   tertiary      no     8741     yes   no
# 31626   57       retired   married    primary      no       70     yes  yes
# 31627   35      services    single  secondary      no       -2      no   no
# 31628   43    unemployed  divorced    primary      no      -70     yes   no
# 31629   35    technician    single   tertiary      no      632      no   no
# 31630   36    management    single   tertiary      no        8      no   no
# 31631   46  entrepreneur   married   tertiary      no      341      no   no
# 31632   33   blue-collar   married  secondary      no        0     yes   no
# 31633   50    technician   married   tertiary      no     3117      no   no
# 31634   30    technician    single   tertiary      no      432     yes  yes
# 31635   35    management   married   tertiary      no        4      no   no
# 31636   48     housemaid   married    primary      no      469      no   no
# 31637   44    technician   married  secondary      no     5163      no   no
# 31638   29   blue-collar   married  secondary      no      721     yes   no
# 31639   38      services    single  secondary      no      570     yes   no
# 31640   43    management    single  secondary      no     2968      no   no
# 31641   37    technician    single   tertiary      no     1309      no   no
# 31642   29    management    single   tertiary      no        0     yes   no
# 31643   53    management  divorced   tertiary      no      380      no  yes
# 31644   32    management    single   tertiary      no      312      no   no
# 31645   57    technician   married  secondary      no      225     yes   no
# 31646   55    management  divorced  secondary      no      204     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# 0      telephone   19   nov        44         2     -1         0  unknown
# 1       cellular   20   jul        91         2     -1         0  unknown
# 2       cellular   18   jul       240         1     -1         0  unknown
# 3       cellular   22   jun       867         1     84         3  success
# 4       cellular    4   feb       380         1     -1         0  unknown
# 5       cellular    2   feb       116         3     -1         0  unknown
# 6      telephone    3   jul       353         2     -1         0  unknown
# 7       cellular    8   jun        97         4     -1         0  unknown
# 8       cellular    4   feb       692         1     -1         0  unknown
